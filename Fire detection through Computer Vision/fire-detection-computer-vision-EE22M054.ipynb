# %% [markdown]
# ## OVERVIEW
# ---
# * Image Preprocessing with OpenCV
#     * Masking
#     * Segmentation
#     * Image Sharpening
# * Transfer Learning with Keras Pretrained Model
# * Feature Extraction
# * Deep Learning Model to Classify the Images

# %%
import datetime as dt
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
sns.set_style('whitegrid')


import os
from keras.applications import xception
from keras.preprocessing import image
from mpl_toolkits.axes_grid1 import ImageGrid
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

import cv2
from scipy.stats import uniform

from tqdm import tqdm
from glob import glob


from keras.models import Model, Sequential
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding, Masking
from keras.utils import np_utils, to_categorical



from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#copying the pretrained models to the cache directory
cache_dir = os.path.expanduser(os.path.join('~', '.keras'))
if not os.path.exists(cache_dir):
    os.makedirs(cache_dir)
models_dir = os.path.join(cache_dir, 'models')
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

#copy the Xception models
# !cp ../input/keras-pretrained-models/xception* ~/.keras/models/
#show
# !ls ~/.keras/models
# Out:
# xception_weights_tf_dim_ordering_tf_kernels.h5
# xception_weights_tf_dim_ordering_tf_kernels_notop.h5

# %%
base_folder = '../input/fire-dataset'
data_folder = '../input/fire-dataset/fire_dataset'
train_data_folder = '../input/fire-dataset/fire_dataset/fire_images'
test_date_folder  = '../input/fire-dataset/fire_dataset/non_fire_images'

categories = ['fire_images', 'non_fire_images']
len_categories = len(categories)

# %%
image_count = {}
train_data = []

for i , category in tqdm(enumerate(categories)):
    class_folder = os.path.join(data_folder, category)
    label = category
    image_count[category] = []
    
    for path in os.listdir(os.path.join(class_folder)):
        image_count[category].append(category)
        train_data.append(['{}/{}'.format(category, path), i, category])
# Out:
# 2it [00:00,  4.22it/s]

# %%
#show image count
for key, value in image_count.items():
    print('{0} -> {1}'.format(key, len(value)))
# Out:
# fire_images -> 755
# non_fire_images -> 244

# %%
#create a dataframe
df = pd.DataFrame(train_data, columns=['file', 'id', 'label'])
df.shape
df.head()
# Out:
# (999, 3)
#                        file  id        label
# 0  fire_images/fire.743.png   0  fire_images
# 1  fire_images/fire.717.png   0  fire_images
# 2  fire_images/fire.157.png   0  fire_images
# 3   fire_images/fire.26.png   0  fire_images
# 4  fire_images/fire.314.png   0  fire_images

# %% [markdown]
# ### IMAGE PREPROCESSING

# %%
#masking function
def create_mask_for_plant(image):
    image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    lower_hsv = np.array([0,0,250])
    upper_hsv = np.array([250,255,255])
    
    mask = cv2.inRange(image_hsv, lower_hsv, upper_hsv)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (11,11))
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    
    return mask

#image segmentation function
def segment_image(image):
    mask = create_mask_for_plant(image)
    output = cv2.bitwise_and(image, image, mask = mask)
    return output/255

#sharpen the image
def sharpen_image(image):
    image_blurred = cv2.GaussianBlur(image, (0, 0), 3)
    image_sharp = cv2.addWeighted(image, 1.5, image_blurred, -0.5, 0)
    return image_sharp

# function to get an image
def read_img(filepath, size):
    img = image.load_img(os.path.join(data_folder, filepath), target_size=size)
    #convert image to array
    img = image.img_to_array(img)
    return img

# %% [markdown]
# ### SHOW SAMPLE IMAGES

# %%
nb_rows = 3
nb_cols = 5
fig, axs = plt.subplots(nb_rows, nb_cols, figsize=(10, 5));
plt.suptitle('SAMPLE IMAGES');
for i in range(0, nb_rows):
    for j in range(0, nb_cols):
        axs[i, j].xaxis.set_ticklabels([]);
        axs[i, j].yaxis.set_ticklabels([]);
        axs[i, j].imshow((read_img(df['file'][np.random.randint(1000)], (255,255)))/255.);
plt.show();

# %% [markdown]
# ### SHOW SAMPLE PROCESSED IMAGE

# %%
#get an image
img = read_img(df['file'][102],(255,255))
#mask
image_mask = create_mask_for_plant(img)
#segmentation
image_segmented = segment_image(img)
#sharpen the image
image_sharpen = sharpen_image(image_segmented)

fig, ax = plt.subplots(1, 4, figsize=(10, 5));
plt.suptitle('SAMPLE PROCESSED IMAGE', x=0.5, y=0.8)
plt.tight_layout(1)

ax[0].set_title('ORIG.', fontsize=12)
ax[1].set_title('MASK', fontsize=12)
ax[2].set_title('SEGMENTED', fontsize=12)
ax[3].set_title('SHARPEN', fontsize=12)


ax[0].imshow(img/255);
ax[1].imshow(image_mask);
ax[2].imshow(image_segmented);
ax[3].imshow(image_sharpen);

# %% [markdown]
# ### XCEPTION BOTTLENECK FEATURE EXTRACTION

# %%
INPUT_SIZE=255

##preprocess the input
X_train = np.zeros((len(df), INPUT_SIZE, INPUT_SIZE, df.shape[1]), dtype='float')
for i, file in tqdm(enumerate(df['file'])):
    #read image
    img = read_img(file,(INPUT_SIZE,INPUT_SIZE))
    #masking and segmentation
    image_segmented = segment_image(img)
    #sharpen
    image_sharpen = sharpen_image(image_segmented)
    x = xception.preprocess_input(np.expand_dims(image_sharpen.copy(), axis=0))
    X_train[i] = x
# Out:
# 999it [01:24, 11.82it/s]

# %%
print('Train Image Shape: ', X_train.shape)
print('Train Image Size: ', X_train.size)
# Out:
# Train Image Shape:  (999, 255, 255, 3)
# Train Image Size:  194879925

# %% [markdown]
# #### SPLIT THE DATA

# %%
y = df['id']
train_x, train_val, y_train, y_val = train_test_split(X_train, y, test_size=0.2, random_state=101)

# %%
print('FIRE IMAGES ON TRAINING DATA: ',y_train[y_train==0].shape[0])
print('NON-FIRE IMAGES ON TRAINING DATA: ',y_train[y_train==1].shape[0])
# Out:
# FIRE IMAGES ON TRAINING DATA:  610
# NON-FIRE IMAGES ON TRAINING DATA:  189

# %%
##get the features
xception_bf = xception.Xception(weights='imagenet', include_top=False, pooling='avg')
bf_train_x = xception_bf.predict(train_x, batch_size=32, verbose=1)
bf_train_val = xception_bf.predict(train_val, batch_size=32, verbose=1)
# Out:
# 25/25 [==============================] - 3s 111ms/step
# 7/7 [==============================] - 1s 97ms/step

# %%
#print shape of feature and size
print('Train Shape: ', bf_train_x.shape)
print('Train Size: ', bf_train_x.size)

print('Validation Shape: ', bf_train_val.shape)
print('Validation Size: ', bf_train_val.size)
# Out:
# Train Shape:  (799, 2048)
# Train Size:  1636352
# Validation Shape:  (200, 2048)
# Validation Size:  409600

# %% [markdown]
# ### DEEP LEARNING MODEL

# %%
#keras Sequential model
model = Sequential()
model.add(Dense(units = 256 , activation = 'relu', input_dim=bf_train_x.shape[1]))
model.add(Dense(units = 64 , activation = 'relu'))
model.add(Dense(units = 1, activation = 'sigmoid'))
model.compile(optimizer = 'adam' , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 541,057
# Trainable params: 541,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train the model @ 100 epochs
history = model.fit(bf_train_x, y_train, epochs=100, batch_size=32);
# Out:
# Epoch 1/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5436 - accuracy: 0.7384
# Epoch 2/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4755 - accuracy: 0.7635
# Epoch 3/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4125 - accuracy: 0.8023
# Epoch 4/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3722 - accuracy: 0.8411
# Epoch 5/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3408 - accuracy: 0.8498
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3184 - accuracy: 0.8536
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3178 - accuracy: 0.8486: 0s - loss: 0.3187 - accuracy: 0.85
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3105 - accuracy: 0.8523
# Epoch 9/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2793 - accuracy: 0.8811
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2640 - accuracy: 0.8899
# Epoch 11/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2495 - accuracy: 0.8899
# Epoch 12/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2467 - accuracy: 0.8899
# Epoch 13/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2397 - accuracy: 0.8961
# Epoch 14/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2345 - accuracy: 0.8974
# Epoch 15/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2210 - accuracy: 0.9111
# Epoch 16/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2080 - accuracy: 0.9161
# Epoch 17/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2069 - accuracy: 0.9061
# Epoch 18/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2275 - accuracy: 0.8899
# Epoch 19/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1947 - accuracy: 0.9136
# Epoch 20/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1900 - accuracy: 0.9262
# Epoch 21/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1804 - accuracy: 0.9224
# Epoch 22/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1976 - accuracy: 0.9186
# Epoch 23/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2141 - accuracy: 0.8936
# Epoch 24/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1863 - accuracy: 0.9136
# Epoch 25/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1945 - accuracy: 0.9136
# Epoch 26/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1796 - accuracy: 0.9237
# Epoch 27/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1599 - accuracy: 0.9362
# Epoch 28/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1629 - accuracy: 0.9249
# Epoch 29/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1549 - accuracy: 0.9362
# Epoch 30/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1502 - accuracy: 0.9362
# Epoch 31/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1466 - accuracy: 0.9399
# Epoch 32/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1471 - accuracy: 0.9412
# Epoch 33/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1671 - accuracy: 0.9237
# Epoch 34/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1699 - accuracy: 0.9262
# Epoch 35/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1760 - accuracy: 0.9212
# Epoch 36/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1431 - accuracy: 0.9437
# Epoch 37/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1614 - accuracy: 0.9274
# Epoch 38/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1430 - accuracy: 0.9337
# Epoch 39/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1366 - accuracy: 0.9387
# Epoch 40/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1540 - accuracy: 0.9362
# Epoch 41/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1491 - accuracy: 0.9362
# Epoch 42/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1695 - accuracy: 0.9337
# Epoch 43/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1285 - accuracy: 0.9462
# Epoch 44/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1497 - accuracy: 0.9349
# Epoch 45/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1268 - accuracy: 0.9462
# Epoch 46/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1300 - accuracy: 0.9399
# Epoch 47/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1206 - accuracy: 0.9549
# Epoch 48/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1499 - accuracy: 0.9299
# Epoch 49/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2144 - accuracy: 0.9086
# Epoch 50/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1677 - accuracy: 0.9262
# Epoch 51/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1221 - accuracy: 0.9549
# Epoch 52/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1403 - accuracy: 0.9449
# Epoch 53/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1468 - accuracy: 0.9299
# Epoch 54/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1476 - accuracy: 0.9374
# Epoch 55/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1321 - accuracy: 0.9474
# Epoch 56/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1273 - accuracy: 0.9462
# Epoch 57/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1201 - accuracy: 0.9499
# Epoch 58/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1157 - accuracy: 0.9549
# Epoch 59/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1394 - accuracy: 0.9412
# Epoch 60/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1657 - accuracy: 0.9299
# Epoch 61/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1160 - accuracy: 0.9462
# Epoch 62/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.9537
# Epoch 63/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1044 - accuracy: 0.9562
# Epoch 64/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1416 - accuracy: 0.9412
# Epoch 65/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1209 - accuracy: 0.9412
# Epoch 66/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1204 - accuracy: 0.95 - 0s 2ms/step - loss: 0.1227 - accuracy: 0.9512
# Epoch 67/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1142 - accuracy: 0.9499
# Epoch 68/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1058 - accuracy: 0.9574
# Epoch 69/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1215 - accuracy: 0.9474
# Epoch 70/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1232 - accuracy: 0.9399
# Epoch 71/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1182 - accuracy: 0.9524
# Epoch 72/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1426 - accuracy: 0.9387
# Epoch 73/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1468 - accuracy: 0.9349
# Epoch 74/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1468 - accuracy: 0.9337
# Epoch 75/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1124 - accuracy: 0.9537
# Epoch 76/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1037 - accuracy: 0.9612
# Epoch 77/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1082 - accuracy: 0.9562
# Epoch 78/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1248 - accuracy: 0.9462
# Epoch 79/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1280 - accuracy: 0.9437
# Epoch 80/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1376 - accuracy: 0.9424
# Epoch 81/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1231 - accuracy: 0.9462
# Epoch 82/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0993 - accuracy: 0.9637
# Epoch 83/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1266 - accuracy: 0.9462
# Epoch 84/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1128 - accuracy: 0.9512
# Epoch 85/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0985 - accuracy: 0.9599
# Epoch 86/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0932 - accuracy: 0.9687
# Epoch 87/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0914 - accuracy: 0.9637
# Epoch 88/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1390 - accuracy: 0.9449
# Epoch 89/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1158 - accuracy: 0.9562
# Epoch 90/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1006 - accuracy: 0.9587
# Epoch 91/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1170 - accuracy: 0.9424
# Epoch 92/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0877 - accuracy: 0.9637
# Epoch 93/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1036 - accuracy: 0.9562
# Epoch 94/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0847 - accuracy: 0.9675
# Epoch 95/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0817 - accuracy: 0.9650
# Epoch 96/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0910 - accuracy: 0.9612
# Epoch 97/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1449 - accuracy: 0.9462
# Epoch 98/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1362 - accuracy: 0.9312
# Epoch 99/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1221 - accuracy: 0.9437
# Epoch 100/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0952 - accuracy: 0.9612

# %% [markdown]
# #### LOSS AND ACCURACY

# %%
fig, ax = plt.subplots(1,2,figsize=(14,5))
ax[0].set_title('TRAINING LOSS');
ax[1].set_title('TRAINING ACCURACY');


ax[0].plot(history.history['loss'], color= 'salmon',lw=2);
ax[1].plot(history.history['accuracy'], color= 'green',lw=2);

# %%
#predict the validation data
predictions = model.predict_classes(bf_train_val)

# %% [markdown]
# #### CLASSIFICATION REPORT

# %%
print(classification_report(y_val, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       145
#            1       0.85      0.75      0.80        55
#
#     accuracy                           0.90       200
#    macro avg       0.88      0.85      0.86       200
# weighted avg       0.89      0.90      0.89       200

# %% [markdown]
# #### CONFUSION MATRIX

# %%
confusion_mat = confusion_matrix(y_val, predictions)

plt.figure(figsize=(10,10))
sns.heatmap(confusion_mat, square=True, annot=True,
            yticklabels=['FIRE_IMG', 'NON_FIRE_IMG'],
            xticklabels=['FIRE_IMG', 'NON_FIRE_IMG']);
plt.title('CONFUSION MATRIX');
plt.xlabel('Y_TRUE');
plt.ylabel("PREDICTIONS");
